# %%
import pandas as pd

# %%
simpsons = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)')

# %%
len(simpsons)
# Out:
# 23

# %%
simpsons[1]
# Out:
#     No.overall  No. inseason                                Title  \
# 0            1             1  "Simpsons Roasting on an Open Fire"
# 1            2             2                    "Bart the Genius"
# 2            3             3                    "Homer's Odyssey"
# 3            4             4      "There's No Disgrace Like Home"
# 4            5             5                   "Bart the General"
# 5            6             6                       "Moaning Lisa"
# 6            7             7           "The Call of the Simpsons"
# 7            8             8                  "The Telltale Head"
# 8            9             9              "Life on the Fast Lane"
# 9           10            10                  "Homer's Night Out"
# 10          11            11                "The Crepes of Wrath"
# 11          12            12                 "Krusty Gets Busted"
# 12          13            13             "Some Enchanted Evening"
#
#                            Directed by  \
# 0                      David Silverman
# 1                      David Silverman
# 2                        Wesley Archer
# 3       Gregg Vanzo & Kent Butterworth
# 4                      David Silverman
# 5                        Wesley Archer
# 6                        Wesley Archer
# 7                           Rich Moore
# 8                      David Silverman
# 9                           Rich Moore
# 10         Wesley Archer & Milton Gray
# 11                           Brad Bird
# 12  David Silverman & Kent Butterworth
#
#                                            Written by  Original air date  \
# 0                                           Mimi Pond  December 17, 1989
# 1                                           Jon Vitti   January 14, 1990
# 2                      Jay Kogen & Wallace Wolodarsky   January 21, 1990
# 3                                Al Jean & Mike Reiss   January 28, 1990
# 4                                   John Swartzwelder   February 4, 1990
# 5                                Al Jean & Mike Reiss  February 11, 1990
# 6                                   John Swartzwelder  February 18, 1990
# 7      Al Jean, Mike Reiss, Sam Simon & Matt Groening  February 25, 1990
# 8                                   John Swartzwelder     March 18, 1990
# 9                                           Jon Vitti     March 25, 1990
# 10  George Meyer, Sam Simon, John Swartzwelder & J...     April 15, 1990
# 11                     Jay Kogen & Wallace Wolodarsky     April 29, 1990
# 12                          Matt Groening & Sam Simon       May 13, 1990
#
#    Prod.code U.S. viewers(millions)
# 0       7G08               26.7[45]
# 1       7G02               24.5[45]
# 2       7G03               27.5[46]
# 3       7G04               20.2[47]
# 4       7G05               27.1[48]
# 5       7G06               27.4[49]
# 6       7G09               27.6[50]
# 7       7G07                 28[51]
# 8       7G11               33.5[52]
# 9       7G10               30.3[53]
# 10      7G13               31.2[54]
# 11      7G12               30.4[55]
# 12      7G01               27.1[56]

# %% [markdown]
# ## target website: https://www.football-data.co.uk/data.php

# %%
df_premier21 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2122/E0.csv')
df_premier21
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal     2     0   H
# 1    E0  14/08/2021  12:30      Man United           Leeds     5     1   H
# 2    E0  14/08/2021  15:00         Burnley        Brighton     1     2   A
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace     3     0   H
# 4    E0  14/08/2021  15:00         Everton     Southampton     3     1   H
# ..   ..         ...    ...             ...             ...   ...   ...  ..
# 375  E0  22/05/2022  16:00  Crystal Palace      Man United     1     0   H
# 376  E0  22/05/2022  16:00       Leicester     Southampton     4     1   H
# 377  E0  22/05/2022  16:00       Liverpool          Wolves     3     1   H
# 378  E0  22/05/2022  16:00        Man City     Aston Villa     3     2   H
# 379  E0  22/05/2022  16:00         Norwich       Tottenham     0     5   A
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# 0       1     0  ...     1.62  0.50      1.75      2.05   1.81   2.13
# 1       1     0  ...     2.25 -1.00      2.05      1.75   2.17   1.77
# 2       1     0  ...     1.62  0.25      1.79      2.15   1.81   2.14
# 3       2     0  ...     1.94 -1.50      2.05      1.75   2.12   1.81
# 4       0     1  ...     1.67 -0.50      2.05      1.88   2.05   1.88
# ..    ...   ...  ...      ...   ...       ...       ...    ...    ...
# 375     1     0  ...     2.04  0.25      1.68      2.15   1.74   2.23
# 376     0     0  ...     2.63 -0.75      1.83      2.07   1.88   2.03
# 377     1     1  ...     3.28 -2.50      2.02      1.77   2.06   1.83
# 378     0     1  ...     3.36 -2.25      2.06      1.84   2.05   1.86
# 379     0     2  ...     2.40  1.50      1.95      1.95   1.96   1.94
#
#      MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0       2.05     2.17     1.80     2.09
# 1       2.19     1.93     2.10     1.79
# 2       1.82     2.19     1.79     2.12
# 3       2.16     1.93     2.06     1.82
# 4       2.08     1.90     2.03     1.86
# ..       ...      ...      ...      ...
# 375     1.88     2.25     1.74     2.16
# 376     1.94     2.26     1.87     2.01
# 377     2.19     1.99     2.07     1.80
# 378     2.09     2.03     2.01     1.87
# 379     2.16     1.98     1.99     1.89
#
# [380 rows x 106 columns]

# %%
df_premier21.rename(columns={'FTHG':'home_goals',
                             'FTAG':'away_goals'}, inplace=True)
df_premier21
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  home_goals  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal           2
# 1    E0  14/08/2021  12:30      Man United           Leeds           5
# 2    E0  14/08/2021  15:00         Burnley        Brighton           1
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace           3
# 4    E0  14/08/2021  15:00         Everton     Southampton           3
# ..   ..         ...    ...             ...             ...         ...
# 375  E0  22/05/2022  16:00  Crystal Palace      Man United           1
# 376  E0  22/05/2022  16:00       Leicester     Southampton           4
# 377  E0  22/05/2022  16:00       Liverpool          Wolves           3
# 378  E0  22/05/2022  16:00        Man City     Aston Villa           3
# 379  E0  22/05/2022  16:00         Norwich       Tottenham           0
#
#      away_goals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# 0             0   H     1     0  ...     1.62  0.50      1.75      2.05
# 1             1   H     1     0  ...     2.25 -1.00      2.05      1.75
# 2             2   A     1     0  ...     1.62  0.25      1.79      2.15
# 3             0   H     2     0  ...     1.94 -1.50      2.05      1.75
# 4             1   H     0     1  ...     1.67 -0.50      2.05      1.88
# ..          ...  ..   ...   ...  ...      ...   ...       ...       ...
# 375           0   H     1     0  ...     2.04  0.25      1.68      2.15
# 376           1   H     0     0  ...     2.63 -0.75      1.83      2.07
# 377           1   H     1     1  ...     3.28 -2.50      2.02      1.77
# 378           2   H     0     1  ...     3.36 -2.25      2.06      1.84
# 379           5   A     0     2  ...     2.40  1.50      1.95      1.95
#
#      PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.81   2.13     2.05     2.17     1.80     2.09
# 1     2.17   1.77     2.19     1.93     2.10     1.79
# 2     1.81   2.14     1.82     2.19     1.79     2.12
# 3     2.12   1.81     2.16     1.93     2.06     1.82
# 4     2.05   1.88     2.08     1.90     2.03     1.86
# ..     ...    ...      ...      ...      ...      ...
# 375   1.74   2.23     1.88     2.25     1.74     2.16
# 376   1.88   2.03     1.94     2.26     1.87     2.01
# 377   2.06   1.83     2.19     1.99     2.07     1.80
# 378   2.05   1.86     2.09     2.03     2.01     1.87
# 379   1.96   1.94     2.16     1.98     1.99     1.89
#
# [380 rows x 106 columns]

# %% [markdown]
# ## extracting table from pdf

# %%
pip install ghostscript
# Out:
# Requirement already satisfied: ghostscript in c:\jupyterlab\resources\jlab_server\lib\site-packages (0.7)
# Requirement already satisfied: setuptools>=38.6.0 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from ghostscript) (58.0.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)

# %%
pip install tk
# Out:
# Collecting tk
#   Downloading tk-0.1.0-py3-none-any.whl (3.9 kB)
# Installing collected packages: tk
# Successfully installed tk-0.1.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)

# %%
pip install "camelot-py[base]"
# Out:
# Requirement already satisfied: camelot-py[base] in c:\jupyterlab\resources\jlab_server\lib\site-packages (0.10.1)
# Requirement already satisfied: chardet>=3.0.4 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from camelot-py[base]) (4.0.0)
# Requirement already satisfied: openpyxl>=2.5.8 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from camelot-py[base]) (3.0.10)
# Requirement already satisfied: pdfminer.six>=20200726 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from camelot-py[base]) (20220524)
# Requirement already satisfied: pandas>=0.23.4 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from camelot-py[base]) (1.3.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from camelot-py[base]) (1.21.2)
# Requirement already satisfied: click>=6.7 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from camelot-py[base]) (8.0.1)
# Requirement already satisfied: PyPDF2>=1.26.0 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from camelot-py[base]) (2.4.0)
# Requirement already satisfied: tabulate>=0.8.9 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from camelot-py[base]) (0.8.10)
# Collecting pdftopng>=0.2.3
#   Downloading pdftopng-0.2.3-cp38-cp38-win_amd64.whl (1.5 MB)
# Requirement already satisfied: ghostscript>=0.7 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from camelot-py[base]) (0.7)
# Collecting opencv-python>=3.4.2.17
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# Requirement already satisfied: colorama in c:\jupyterlab\resources\jlab_server\lib\site-packages (from click>=6.7->camelot-py[base]) (0.4.4)
# Requirement already satisfied: setuptools>=38.6.0 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from ghostscript>=0.7->camelot-py[base]) (58.0.4)
# Requirement already satisfied: et-xmlfile in c:\jupyterlab\resources\jlab_server\lib\site-packages (from openpyxl>=2.5.8->camelot-py[base]) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from pandas>=0.23.4->camelot-py[base]) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from pandas>=0.23.4->camelot-py[base]) (2.8.2)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\anves\python\python38\site-packages (from pdfminer.six>=20200726->camelot-py[base]) (2.0.10)
# Requirement already satisfied: cryptography>=36.0.0 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from pdfminer.six>=20200726->camelot-py[base]) (37.0.2)
# Requirement already satisfied: cffi>=1.12 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from cryptography>=36.0.0->pdfminer.six>=20200726->camelot-py[base]) (1.14.6)
# Requirement already satisfied: pycparser in c:\jupyterlab\resources\jlab_server\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six>=20200726->camelot-py[base]) (2.20)
# Requirement already satisfied: typing-extensions in c:\jupyterlab\resources\jlab_server\lib\site-packages (from PyPDF2>=1.26.0->camelot-py[base]) (4.2.0)
# Requirement already satisfied: six>=1.5 in c:\jupyterlab\resources\jlab_server\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23.4->camelot-py[base]) (1.16.0)
# Installing collected packages: pdftopng, opencv-python
# Successfully installed opencv-python-4.6.0.66 pdftopng-0.2.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)
# WARNING: Ignoring invalid distribution -harset-normalizer (c:\jupyterlab\resources\jlab_server\lib\site-packages)

# %%
import camelot

# %%
tables = camelot.read_pdf('kotak.pdf', pages='1')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15236/4188631664.py in <module>
# ----> 1 tables = camelot.read_pdf('kotak.pdf', pages='1')
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\camelot\io.py in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     111         p = PDFHandler(filepath, pages=pages, password=password)
#     112         kwargs = remove_extra(kwargs, flavor=flavor)
# --> 113         tables = p.parse(
#     114             flavor=flavor,
#     115             suppress_stdout=suppress_stdout,
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\camelot\handlers.py in parse(self, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     174             parser = Lattice(**kwargs) if flavor == "lattice" else Stream(**kwargs)
#     175             for p in pages:
# --> 176                 t = parser.extract_tables(
#     177                     p, suppress_stdout=suppress_stdout, layout_kwargs=layout_kwargs
#     178                 )
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\camelot\parsers\lattice.py in extract_tables(self, filename, suppress_stdout, layout_kwargs)
#     419             return []
#     420
# --> 421         self.backend.convert(self.filename, self.imagename)
#     422
#     423         self._generate_table_bbox()
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\camelot\backends\ghostscript_backend.py in convert(self, pdf_path, png_path, resolution)
#      29     def convert(self, pdf_path, png_path, resolution=300):
#      30         if not self.installed():
# ---> 31             raise OSError(
#      32                 "Ghostscript is not installed. You can install it using the instructions"
#      33                 " here: https://camelot-py.readthedocs.io/en/master/user/install-deps.html"
#
# OSError: Ghostscript is not installed. You can install it using the instructions here: https://camelot-py.readthedocs.io/en/master/user/install-deps.html
